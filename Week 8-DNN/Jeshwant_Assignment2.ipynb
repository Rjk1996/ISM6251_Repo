# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix,recall_score,f1_score,precision_score
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV

# %% [markdown]
# # Importing the Refined Data set

# %%
X_test = pd.read_csv("X_test.csv")
y_test = pd.read_csv("y_test.csv")
X_train = pd.read_csv("X_train.csv")
y_train = pd.read_csv("y_train.csv")

# %%
performance = pd.DataFrame({"model": [], "Accuracy": [], "Precision": [], "Recall": [], "F1": []})

# %% [markdown]
# ## Logistic Regression

# %%
log_reg_model = LogisticRegression()
_ = log_reg_model.fit(X_train, y_train)
# Out:
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model_preds = log_reg_model.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"svm_linear", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#         model  Accuracy  Precision    Recall        F1
# 0  svm_linear  0.883333   0.892272  0.883333  0.885684

# %% [markdown]
# ## RandomizedSearchCV Logistic Regression

# %%
score_measure = "recall"
LR=LogisticRegression()
kfolds = 5
param_grid = {'C': [0.1, 1, 10,0.001],
              "solver" : [ 'lbfgs', 'liblinear'],
              "penalty" : ['l1','l2','lasso','elastic']} 
  
grid = RandomizedSearchCV(LR, param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
print(f"The best {score_measure} score is {grid.best_score_}")
print(f"... with parameters: {grid.best_params_}")

bestRecallTree = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END .C=1, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 2/5] END .C=1, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 3/5] END .C=1, penalty=l2, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 4/5] END .C=1, penalty=l2, solver=liblinear;, score=0.893 total time=   0.0s
# [CV 5/5] END .C=1, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 1/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.821 total time=   0.0s
# [CV 2/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.821 total time=   0.0s
# [CV 3/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.857 total time=   0.0s
# [CV 5/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.679 total time=   0.0s
# [CV 1/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=10, penalty=l1, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 2/5] END C=10, penalty=l1, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=10, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 4/5] END C=10, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 5/5] END C=10, penalty=l1, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.001, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=0.001, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=0.001, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=0.001, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=0.001, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# The best recall score is 0.9714285714285715
# ... with parameters: {'solver': 'liblinear', 'penalty': 'l1', 'C': 10}
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 35 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'l1', 'none' (deprecated)} or None. Got 'lasso' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'l1', 'none' (deprecated)} or None. Got 'elastic' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.9        0.78571429        nan 0.97142857
#         nan        nan        nan        nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model_preds = bestRecallTree.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"LR_random", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#         model  Accuracy  Precision    Recall        F1
# 0  svm_linear  0.883333   0.892272  0.883333  0.885684
# 0   LR_random  0.966667   0.970833  0.966667  0.967619

# %% [markdown]
# ## GridSearchCV Logistic Regression

# %%
score_measure = "recall"
kfolds = 5
param_grid = {'C': [0.1, 1, 10], 
              'solver' : [ 'lbfgs', 'liblinear'],
              'penalty' : ['l1','l2','lasso','elastic']} 
  
grid = GridSearchCV(LogisticRegression(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
print(f"The best {score_measure} score is {grid.best_score_}")
print(f"... with parameters: {grid.best_params_}")

bestRecallTree = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .....C=0.1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.714 total time=   0.0s
# [CV 2/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.536 total time=   0.0s
# [CV 3/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.500 total time=   0.0s
# [CV 4/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.607 total time=   0.0s
# [CV 5/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.500 total time=   0.0s
# [CV 1/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.821 total time=   0.0s
# [CV 2/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.821 total time=   0.0s
# [CV 3/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.750 total time=   0.0s
# [CV 4/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.857 total time=   0.0s
# [CV 5/5] END ...C=0.1, penalty=l2, solver=lbfgs;, score=0.679 total time=   0.0s
# [CV 1/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.786 total time=   0.0s
# [CV 2/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 3/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.571 total time=   0.0s
# [CV 4/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.750 total time=   0.0s
# [CV 5/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.643 total time=   0.0s
# [CV 1/5] END ..C=0.1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ..C=0.1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ..C=0.1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ..C=0.1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ..C=0.1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=0.1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .......C=1, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END .C=1, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 2/5] END .C=1, penalty=l1, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END .C=1, penalty=l1, solver=liblinear;, score=0.857 total time=   0.0s
# [CV 4/5] END .C=1, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 5/5] END .C=1, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 1/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.964 total time=   0.0s
# [CV 2/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.821 total time=   0.0s
# [CV 3/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.857 total time=   0.0s
# [CV 4/5] END .....C=1, penalty=l2, solver=lbfgs;, score=1.000 total time=   0.0s
# [CV 5/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.857 total time=   0.0s
# [CV 1/5] END .C=1, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 2/5] END .C=1, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 3/5] END .C=1, penalty=l2, solver=liblinear;, score=0.821 total time=   0.0s
# [CV 4/5] END .C=1, penalty=l2, solver=liblinear;, score=0.893 total time=   0.0s
# [CV 5/5] END .C=1, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 1/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ....C=1, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=1, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END ..C=1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ..C=1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ..C=1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ..C=1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ..C=1, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=1, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ......C=10, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END C=10, penalty=l1, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 2/5] END C=10, penalty=l1, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=10, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 4/5] END C=10, penalty=l1, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 5/5] END C=10, penalty=l1, solver=liblinear;, score=1.000 total time=   0.0s
# [CV 1/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.929 total time=   0.0s
# [CV 2/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.893 total time=   0.0s
# [CV 3/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.893 total time=   0.0s
# [CV 4/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.893 total time=   0.0s
# [CV 5/5] END ....C=10, penalty=l2, solver=lbfgs;, score=0.929 total time=   0.0s
# [CV 1/5] END C=10, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 2/5] END C=10, penalty=l2, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 3/5] END C=10, penalty=l2, solver=liblinear;, score=0.929 total time=   0.0s
# [CV 4/5] END C=10, penalty=l2, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 5/5] END C=10, penalty=l2, solver=liblinear;, score=0.964 total time=   0.0s
# [CV 1/5] END ...C=10, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ...C=10, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ...C=10, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ...C=10, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ...C=10, penalty=lasso, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=10, penalty=lasso, solver=liblinear;, score=nan total time=   0.0s
# [CV 1/5] END .C=10, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END .C=10, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END .C=10, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END .C=10, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END .C=10, penalty=elastic, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=10, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 2/5] END C=10, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 3/5] END C=10, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 4/5] END C=10, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# [CV 5/5] END C=10, penalty=elastic, solver=liblinear;, score=nan total time=   0.0s
# The best recall score is 0.9714285714285715
# ... with parameters: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 75 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'l1', 'none' (deprecated)} or None. Got 'lasso' instead.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'l1', 'none' (deprecated)} or None. Got 'elastic' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.57142857 0.78571429 0.7               nan        nan
#         nan        nan        nan 0.95       0.9        0.9
#         nan        nan        nan        nan        nan 0.97142857
#  0.90714286 0.95              nan        nan        nan        nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model_preds = bestRecallTree.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"LR_grid", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#         model  Accuracy  Precision    Recall        F1
# 0  svm_linear  0.883333   0.892272  0.883333  0.885684
# 0   LR_random  0.966667   0.970833  0.966667  0.967619
# 0     LR_grid  0.966667   0.970833  0.966667  0.967619

# %%
score_measure = "recall"
kfolds = 5
param_grid = {'C': [0.1, 1, 10], 
              'gamma': [1, 0.1, 0.01, 0.001],
              'kernel': ['linear','poly','rbf']} 
  
grid = RandomizedSearchCV(SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
print(f"The best {score_measure} score is {grid.best_score_}")
print(f"... with parameters: {grid.best_params_}")

bestRecallTree = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.821 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.786 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.857 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.786 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.821 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.857 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.929 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.786 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.857 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.929 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.643 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.571 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.643 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.571 total time=   0.0s
# The best recall score is 0.9714285714285715
# ... with parameters: {'kernel': 'linear', 'gamma': 0.1, 'C': 1}
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Decision Tree

# %%
DTmodel = DecisionTreeClassifier()
_ = DTmodel.fit(X_train,y_train)

# %%
model_preds = DTmodel.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"DT", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#         model  Accuracy  Precision    Recall        F1
# 0  svm_linear  0.883333   0.892272  0.883333  0.885684
# 0   LR_random  0.966667   0.970833  0.966667  0.967619
# 0     LR_grid  0.966667   0.970833  0.966667  0.967619
# 0          DT  1.000000   1.000000  1.000000  1.000000

# %% [markdown]
# ## Decision tree model using the randomsearch

# %%
score_measure = "recall"
kfolds = 5

param_grid = {
    'min_samples_split': np.arange(25,30),  
    'min_samples_leaf': np.arange(1,5),
    'min_impurity_decrease': np.arange(0.0000, 0.0004, 0.0001),
    'max_leaf_nodes': np.arange(187,192), 
    'max_depth': np.arange(29,33), 
    'criterion': ['entropy'],
}

dtree = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator = dtree, param_grid=param_grid, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

_ = grid_search.fit(X_train, y_train)

print(f"The best {score_measure} score is {grid_search.best_score_}")
print(f"... with parameters: {grid_search.best_params_}")

bestRecallTree = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 1600 candidates, totalling 8000 fits
# The best recall score is nan
# ... with parameters: {'criterion': 'entropy', 'max_depth': 29, 'max_leaf_nodes': 187, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 25}
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan ... nan nan nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the train scores are non-finite: [nan nan nan ... nan nan nan]
#   warnings.warn(

# %%
model_preds = bestRecallTree.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"DT_random", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#         model  Accuracy  Precision    Recall        F1
# 0  svm_linear  0.883333   0.892272  0.883333  0.885684
# 0   LR_random  0.966667   0.970833  0.966667  0.967619
# 0     LR_grid  0.966667   0.970833  0.966667  0.967619
# 0          DT  1.000000   1.000000  1.000000  1.000000
# 0   DT_random  0.883333   0.957576  0.883333  0.896475

# %% [markdown]
# ## Decision tree model using the Gridsearch

# %%
score_measure = "recall"
kfolds = 5

param_grid = {
    'min_samples_split': np.arange(25,32),  
    'min_samples_leaf': np.arange(3,6),
    'min_impurity_decrease': np.arange(0.0001, 0.0004, 0.0001),
    'max_leaf_nodes': np.arange(194,200), 
    'max_depth': np.arange(15,21), 
    'criterion': ['entropy'],
}

dtree = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator = dtree, param_grid=param_grid, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

_ = grid_search.fit(X_train, y_train)

print(f"The best {score_measure} score is {grid_search.best_score_}")
print(f"... with parameters: {grid_search.best_params_}")

bestRecallTree = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 2268 candidates, totalling 11340 fits
# The best recall score is nan
# ... with parameters: {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 194, 'min_impurity_decrease': 0.0001, 'min_samples_leaf': 3, 'min_samples_split': 25}
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan ... nan nan nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the train scores are non-finite: [nan nan nan ... nan nan nan]
#   warnings.warn(

# %%
model_preds = bestRecallTree.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"DT_gridsearch", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#            model  Accuracy  Precision    Recall        F1
# 0     svm_linear  0.883333   0.892272  0.883333  0.885684
# 0      LR_random  0.966667   0.970833  0.966667  0.967619
# 0        LR_grid  0.966667   0.970833  0.966667  0.967619
# 0             DT  1.000000   1.000000  1.000000  1.000000
# 0      DT_random  0.883333   0.957576  0.883333  0.896475
# 0  DT_gridsearch  0.883333   0.957576  0.883333  0.896475

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

svm = SVC()
svm.fit(X_train, y_train)
print('Accuracy of SVM classifier on this training is {:.2f}'
     .format(svm.score(X_train, y_train)))
# Out:
# Accuracy of SVM classifier on this training is 0.68
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svm_lin_model = SVC(kernel="linear" , probability=True)
_ = svm_lin_model.fit(X_train, np.ravel(y_train))

# %%
model_preds = svm_lin_model.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"svm_lin_model", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#            model  Accuracy  Precision    Recall        F1
# 0     svm_linear  0.883333   0.892272  0.883333  0.885684
# 0      LR_random  0.966667   0.970833  0.966667  0.967619
# 0        LR_grid  0.966667   0.970833  0.966667  0.967619
# 0             DT  1.000000   1.000000  1.000000  1.000000
# 0      DT_random  0.883333   0.957576  0.883333  0.896475
# 0  DT_gridsearch  0.883333   0.957576  0.883333  0.896475
# 0  svm_lin_model  0.983333   0.987500  0.983333  0.984383

# %% [markdown]
# ## SVM classification model using RBF kernel

# %%
svm_rbf_model = SVC(kernel="rbf", C=10)
_ = svm_rbf_model.fit(X_train, np.ravel(y_train))

# %%
svm_rbf_model = svm_lin_model.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"svm_rbf_model", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#            model  Accuracy  Precision    Recall        F1
# 0     svm_linear  0.883333   0.892272  0.883333  0.885684
# 0      LR_random  0.966667   0.970833  0.966667  0.967619
# 0        LR_grid  0.966667   0.970833  0.966667  0.967619
# 0             DT  1.000000   1.000000  1.000000  1.000000
# 0      DT_random  0.883333   0.957576  0.883333  0.896475
# 0  DT_gridsearch  0.883333   0.957576  0.883333  0.896475
# 0  svm_lin_model  0.983333   0.987500  0.983333  0.984383
# 0  svm_rbf_model  0.983333   0.987500  0.983333  0.984383

# %% [markdown]
# ## SVM classification model using polynomial kernel

# %%
svm_poly_model = SVC(kernel="poly", degree=3, coef0=1, C=10)
_ = svm_poly_model.fit(X_train, np.ravel(y_train))

# %%
svm_rbf_model = svm_poly_model.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"svm_poly_model", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#             model  Accuracy  Precision    Recall        F1
# 0      svm_linear  0.883333   0.892272  0.883333  0.885684
# 0       LR_random  0.966667   0.970833  0.966667  0.967619
# 0         LR_grid  0.966667   0.970833  0.966667  0.967619
# 0              DT  1.000000   1.000000  1.000000  1.000000
# 0       DT_random  0.883333   0.957576  0.883333  0.896475
# 0   DT_gridsearch  0.883333   0.957576  0.883333  0.896475
# 0   svm_lin_model  0.983333   0.987500  0.983333  0.984383
# 0   svm_rbf_model  0.983333   0.987500  0.983333  0.984383
# 0  svm_poly_model  0.983333   0.987500  0.983333  0.984383

# %% [markdown]
# ## GridSearchCV SVM

# %%
score_measure = "recall"
kfolds = 5
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear','poly','rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)
print(f"The best {score_measure} score is {grid.best_score_}")
print(f"... with parameters: {grid.best_params_}")

bestRecallTree = grid.best_estimator_
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.857 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.857 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.929 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.821 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.893 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.893 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.929 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.536 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.643 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.500 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.607 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.607 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.893 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.464 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.857 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.857 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.679 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.643 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.643 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.857 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.929 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.643 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.571 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.679 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.536 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.679 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.679 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.643 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.464 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.429 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.464 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.429 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=1.000 total time=   0.0s
# ...
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.964 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.857 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.929 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.929 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.964 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.929 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.964 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.893 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.929 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.929 total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=1.000 total time=   0.0s
# [CV 1/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.571 total time=   0.0s
# [CV 2/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.679 total time=   0.0s
# [CV 3/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.536 total time=   0.0s
# [CV 4/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.679 total time=   0.0s
# [CV 5/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.679 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.929 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.857 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=1.000 total time=   0.0s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# The best recall score is 0.9714285714285715
# ... with parameters: {'C': 1, 'gamma': 1, 'kernel': 'linear'}

# %%
model_preds = bestRecallTree.predict(X_test)
performance = pd.concat([performance, pd.DataFrame({'model':"Gridsearch_svm", 
                                                    'Accuracy': accuracy_score(y_test, model_preds) , 
                                                    'Precision': precision_score(y_test, model_preds, average='weighted') , 
                                                    'Recall': recall_score(y_test, model_preds, average='weighted'), 
                                                    'F1': f1_score(y_test, model_preds, average='weighted') }, index=[0])])
performance
# Out:
#             model  Accuracy  Precision    Recall        F1
# 0      svm_linear  0.883333   0.892272  0.883333  0.885684
# 0       LR_random  0.966667   0.970833  0.966667  0.967619
# 0         LR_grid  0.966667   0.970833  0.966667  0.967619
# 0              DT  1.000000   1.000000  1.000000  1.000000
# 0       DT_random  0.883333   0.957576  0.883333  0.896475
# 0   DT_gridsearch  0.883333   0.957576  0.883333  0.896475
# 0   svm_lin_model  0.983333   0.987500  0.983333  0.984383
# 0   svm_rbf_model  0.983333   0.987500  0.983333  0.984383
# 0  svm_poly_model  0.983333   0.987500  0.983333  0.984383
# 0  bestRecallTree  0.983333   0.987500  0.983333  0.984383
# 0  Gridsearch_svm  0.983333   0.987500  0.983333  0.984383

# %% [markdown]
# # Neutral Networks

# %%
from sklearn.neural_network import MLPClassifier

# %%
# %%time

ann = MLPClassifier(hidden_layer_sizes=(60,60,60), solver='adam', max_iter=200)
_ = ann.fit(X_train, y_train)
# Out:
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1098: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# CPU times: total: 1.58 s
# Wall time: 483 ms
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# %%time
y_pred = ann.predict(X_test)
# Out:
# CPU times: total: 0 ns
# Wall time: 4 ms

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      0.90      0.93        30
#            2       1.00      1.00      1.00         4
#            3       0.89      0.94      0.92        18
#            4       0.80      0.80      0.80         5
#            5       0.50      0.67      0.57         3
#
#     accuracy                           0.90        60
#    macro avg       0.83      0.86      0.84        60
# weighted avg       0.91      0.90      0.90        60

# %% [markdown]
# ## Nueral Network model With RandomizedSearchCV

# %%
# %%time

score_measure = "recall"
kfolds = 5

param_grid = {
    'hidden_layer_sizes': [(40,40,40),
                          (60,60,60),(70,70,70),(30,30,30,30)],
    'activation': ['tanh', 'relu'],
    'solver': ['adam', 'sgd'],
    'alpha': [0, .2, .5, .7, 1],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'learning_rate_init': [0.001, 0.01, 0.1, 0.2, 0.5],
    'max_iter': [5000]
}

ann = MLPClassifier()
grid_search = RandomizedSearchCV(estimator = ann, param_distributions=param_grid, cv=kfolds, n_iter=100,
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

_ = grid_search.fit(X_train, y_train)

bestRecallTree = grid_search.best_estimator_

print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# {'solver': 'sgd', 'max_iter': 5000, 'learning_rate_init': 0.5, 'learning_rate': 'adaptive', 'hidden_layer_sizes': (30, 30, 30, 30), 'alpha': 0.7, 'activation': 'relu'}
# CPU times: total: 2.22 s
# Wall time: 1min 7s
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the train scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1098: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# %%time
y_pred = bestRecallTree.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67        30
#            2       0.00      0.00      0.00         4
#            3       0.00      0.00      0.00        18
#            4       0.00      0.00      0.00         5
#            5       0.00      0.00      0.00         3
#
#     accuracy                           0.50        60
#    macro avg       0.10      0.20      0.13        60
# weighted avg       0.25      0.50      0.33        60
#
# CPU times: total: 125 ms
# Wall time: 24 ms
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Nueral Network model With GridSearchCV

# %%
# %%time

score_measure = "recall"
kfolds = 5

param_grid = {
    'hidden_layer_sizes': [ (40,20), (50,30), (50,40,30), (80,)],
    'activation': ['relu','tanh'],
    'solver': ['adam'],
    'alpha': [.3, .5, 1],
    'learning_rate': ['adaptive', 'invscaling'],
    'learning_rate_init': [0.005, 0.01, 0.15],
    'max_iter': [5000]
}

ann = MLPClassifier()
grid_search = GridSearchCV(estimator = ann, param_grid=param_grid, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

_ = grid_search.fit(X_train, y_train)

bestRecallTree = grid_search.best_estimator_

print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the train scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\Jeshwant\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'activation': 'relu', 'alpha': 0.3, 'hidden_layer_sizes': (40, 20), 'learning_rate': 'adaptive', 'learning_rate_init': 0.005, 'max_iter': 5000, 'solver': 'adam'}
# CPU times: total: 3.89 s
# Wall time: 39.4 s

# %%
# %%time
y_pred = bestRecallTree.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.93      0.97        30
#            2       1.00      1.00      1.00         4
#            3       0.95      1.00      0.97        18
#            4       1.00      1.00      1.00         5
#            5       0.75      1.00      0.86         3
#
#     accuracy                           0.97        60
#    macro avg       0.94      0.99      0.96        60
# weighted avg       0.97      0.97      0.97        60
#
# CPU times: total: 46.9 ms
# Wall time: 12 ms

# %% [markdown]
# ## Using Keras

# %% [markdown]
# ## Deep Network

# %%
import os
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import tensorflow as tf
from tensorflow import keras

# fix random seed for reproducibility
np.random.seed(1)
tf.random.set_seed(1)

# %%
X_test.shape
# Out:
# (60, 9)

# %%
y_train.value_counts()
# Out:
# Drug
# 1       61
# 3       36
# 4       18
# 5       13
# 2       12
# dtype: int64

# %%
# %%time

# create model stucture
model = keras.models.Sequential()
model.add(keras.layers.Input(9))
model.add(keras.layers.Dense(60, activation='relu'))
model.add(keras.layers.Dense(60, activation='relu'))
model.add(keras.layers.Dense(60, activation='relu'))
model.add(keras.layers.Dense(6, activation='softmax')) # final layer, 10 categories


# compile
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# if you want to overide the defaults for the optimizer....
#adam = keras.optimizers.Adam(learning_rate=0.01)
#model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
# Out:
# CPU times: total: 62.5 ms
# Wall time: 67.9 ms

# %%
# %%time

# fit the model
history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    epochs=25, batch_size=100)
# Out:
# Epoch 1/25
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0581 - accuracy: 0.9857 - val_loss: 0.1705 - val_accuracy: 0.9333
# Epoch 2/25
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9333
# Epoch 3/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9333
# Epoch 4/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9500
# Epoch 5/25
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0530 - accuracy: 0.9857 - val_loss: 0.1827 - val_accuracy: 0.9500
# Epoch 6/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0537 - accuracy: 0.9857 - val_loss: 0.1886 - val_accuracy: 0.9333
# Epoch 7/25
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0508 - accuracy: 0.9929 - val_loss: 0.1827 - val_accuracy: 0.9333
# Epoch 8/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 0.9333
# Epoch 9/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.1772 - val_accuracy: 0.9333
# Epoch 10/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0528 - accuracy: 0.9929 - val_loss: 0.1637 - val_accuracy: 0.9333
# Epoch 11/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0543 - accuracy: 0.9857 - val_loss: 0.1591 - val_accuracy: 0.9500
# Epoch 12/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0496 - accuracy: 0.9929 - val_loss: 0.1781 - val_accuracy: 0.9333
# Epoch 13/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0515 - accuracy: 0.9929 - val_loss: 0.1883 - val_accuracy: 0.9333
# Epoch 14/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9333
# Epoch 15/25
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9333
# Epoch 16/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 17/25
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0539 - accuracy: 0.9929 - val_loss: 0.1764 - val_accuracy: 0.9500
# Epoch 18/25
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0486 - accuracy: 0.9857 - val_loss: 0.1649 - val_accuracy: 0.9500
# Epoch 19/25
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0508 - accuracy: 0.9929 - val_loss: 0.1677 - val_accuracy: 0.9333
# Epoch 20/25
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9333
# Epoch 21/25
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.9333
# Epoch 22/25
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.1806 - val_accuracy: 0.9333
# Epoch 23/25
# 2/2 [==============================] - 0s 56ms/step - loss: 0.0478 - accuracy: 0.9929 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 24/25
# 2/2 [==============================] - 0s 52ms/step - loss: 0.0479 - accuracy: 0.9929 - val_loss: 0.1703 - val_accuracy: 0.9500
# Epoch 25/25
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0471 - accuracy: 0.9929 - val_loss: 0.1693 - val_accuracy: 0.9500
# CPU times: total: 8.53 s
# Wall time: 1.72 s

# %%
# evaluate the model

scores = model.evaluate(X_test, y_test, verbose=0)
scores
# In results, first is loss, second is accuracy
# Out:
# [0.16926123201847076, 0.949999988079071]

# %%
# let's format this into a better output...

print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 0.17
# accuracy: 95.00%

# %% [markdown]
# ## Wide and Deep Network

# %%
#Define the model: for multi-class

model = keras.models.Sequential()

model.add(keras.layers.Input(shape=9))
model.add(keras.layers.Dense(40, activation='relu'))
model.add(keras.layers.Dense(20, activation='relu'))
model.add(keras.layers.Dense(6, activation='softmax'))

# %%
# Compile model

#Optimizer:
adam = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
# Fit the model

history = model.fit(X_train, y_train, 
                    validation_data=(X_test, y_test), 
                    epochs=60, batch_size=100)
# Out:
# Epoch 1/60
# 2/2 [==============================] - 0s 136ms/step - loss: 0.2144 - accuracy: 0.9286 - val_loss: 0.2635 - val_accuracy: 0.8833
# Epoch 2/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2212 - accuracy: 0.9286 - val_loss: 0.2894 - val_accuracy: 0.8833
# Epoch 3/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2246 - accuracy: 0.9143 - val_loss: 0.2404 - val_accuracy: 0.8833
# Epoch 4/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.2090 - accuracy: 0.9429 - val_loss: 0.2240 - val_accuracy: 0.9000
# Epoch 5/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1992 - accuracy: 0.9357 - val_loss: 0.2486 - val_accuracy: 0.9000
# Epoch 6/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1892 - accuracy: 0.9500 - val_loss: 0.2633 - val_accuracy: 0.9000
# Epoch 7/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1921 - accuracy: 0.9357 - val_loss: 0.2170 - val_accuracy: 0.9500
# Epoch 8/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1921 - accuracy: 0.9429 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 9/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1883 - accuracy: 0.9429 - val_loss: 0.2384 - val_accuracy: 0.9000
# Epoch 10/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1875 - accuracy: 0.9214 - val_loss: 0.2074 - val_accuracy: 0.9500
# Epoch 11/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1829 - accuracy: 0.9429 - val_loss: 0.2174 - val_accuracy: 0.9333
# Epoch 12/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1703 - accuracy: 0.9643 - val_loss: 0.2590 - val_accuracy: 0.9000
# Epoch 13/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2148 - accuracy: 0.9286 - val_loss: 0.2168 - val_accuracy: 0.9167
# Epoch 14/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1893 - accuracy: 0.9429 - val_loss: 0.2352 - val_accuracy: 0.9000
# Epoch 15/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.2000 - accuracy: 0.9429 - val_loss: 0.2564 - val_accuracy: 0.8833
# Epoch 16/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1905 - accuracy: 0.9286 - val_loss: 0.2372 - val_accuracy: 0.8833
# Epoch 17/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1776 - accuracy: 0.9429 - val_loss: 0.2096 - val_accuracy: 0.9167
# Epoch 18/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1773 - accuracy: 0.9571 - val_loss: 0.1886 - val_accuracy: 0.9167
# Epoch 19/60
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1748 - accuracy: 0.9500 - val_loss: 0.2106 - val_accuracy: 0.9167
# Epoch 20/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1702 - accuracy: 0.9357 - val_loss: 0.2183 - val_accuracy: 0.9167
# Epoch 21/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1757 - accuracy: 0.9357 - val_loss: 0.1933 - val_accuracy: 0.9167
# Epoch 22/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1466 - accuracy: 0.9571 - val_loss: 0.2126 - val_accuracy: 0.9000
# Epoch 23/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1546 - accuracy: 0.9429 - val_loss: 0.1924 - val_accuracy: 0.9167
# Epoch 24/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1465 - accuracy: 0.9571 - val_loss: 0.1740 - val_accuracy: 0.9333
# Epoch 25/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1464 - accuracy: 0.9571 - val_loss: 0.1888 - val_accuracy: 0.9333
# Epoch 26/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1521 - accuracy: 0.9643 - val_loss: 0.1860 - val_accuracy: 0.9167
# Epoch 27/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1370 - accuracy: 0.9714 - val_loss: 0.1743 - val_accuracy: 0.9500
# Epoch 28/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1466 - accuracy: 0.9714 - val_loss: 0.1792 - val_accuracy: 0.9167
# Epoch 29/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1378 - accuracy: 0.9786 - val_loss: 0.2029 - val_accuracy: 0.9000
# Epoch 30/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1402 - accuracy: 0.9500 - val_loss: 0.1908 - val_accuracy: 0.9167
# Epoch 31/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1560 - accuracy: 0.9500 - val_loss: 0.1694 - val_accuracy: 0.9500
# Epoch 32/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1445 - accuracy: 0.9571 - val_loss: 0.1901 - val_accuracy: 0.9000
# Epoch 33/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1363 - accuracy: 0.9714 - val_loss: 0.1825 - val_accuracy: 0.9000
# Epoch 34/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1246 - accuracy: 0.9714 - val_loss: 0.1640 - val_accuracy: 0.9500
# Epoch 35/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1331 - accuracy: 0.9643 - val_loss: 0.1691 - val_accuracy: 0.9333
# Epoch 36/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1200 - accuracy: 0.9786 - val_loss: 0.1853 - val_accuracy: 0.9000
# Epoch 37/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1300 - accuracy: 0.9643 - val_loss: 0.1509 - val_accuracy: 0.9500
# Epoch 38/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1231 - accuracy: 0.9786 - val_loss: 0.1640 - val_accuracy: 0.9333
# Epoch 39/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1244 - accuracy: 0.9714 - val_loss: 0.1583 - val_accuracy: 0.9333
# Epoch 40/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1168 - accuracy: 0.9714 - val_loss: 0.1509 - val_accuracy: 0.9500
# Epoch 41/60
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1155 - accuracy: 0.9643 - val_loss: 0.1618 - val_accuracy: 0.9167
# Epoch 42/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1112 - accuracy: 0.9857 - val_loss: 0.1647 - val_accuracy: 0.9333
# Epoch 43/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1079 - accuracy: 0.9857 - val_loss: 0.1599 - val_accuracy: 0.9333
# Epoch 44/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1108 - accuracy: 0.9714 - val_loss: 0.1492 - val_accuracy: 0.9333
# Epoch 45/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1159 - accuracy: 0.9643 - val_loss: 0.1523 - val_accuracy: 0.9500
# Epoch 46/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1051 - accuracy: 0.9786 - val_loss: 0.1631 - val_accuracy: 0.9167
# Epoch 47/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1172 - accuracy: 0.9571 - val_loss: 0.1470 - val_accuracy: 0.9333
# Epoch 48/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1226 - accuracy: 0.9643 - val_loss: 0.1585 - val_accuracy: 0.9167
# Epoch 49/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1090 - accuracy: 0.9786 - val_loss: 0.1724 - val_accuracy: 0.9333
# Epoch 50/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1179 - accuracy: 0.9714 - val_loss: 0.1444 - val_accuracy: 0.9500
# Epoch 51/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1107 - accuracy: 0.9714 - val_loss: 0.1594 - val_accuracy: 0.9167
# Epoch 52/60
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1231 - accuracy: 0.9643 - val_loss: 0.1753 - val_accuracy: 0.9167
# Epoch 53/60
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1247 - accuracy: 0.9571 - val_loss: 0.1621 - val_accuracy: 0.9333
# Epoch 54/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1237 - accuracy: 0.9500 - val_loss: 0.1630 - val_accuracy: 0.9333
# Epoch 55/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1363 - accuracy: 0.9429 - val_loss: 0.1517 - val_accuracy: 0.9167
# Epoch 56/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1066 - accuracy: 0.9643 - val_loss: 0.1848 - val_accuracy: 0.9000
# Epoch 57/60
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1467 - accuracy: 0.9500 - val_loss: 0.1305 - val_accuracy: 0.9500
# Epoch 58/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1273 - accuracy: 0.9571 - val_loss: 0.1239 - val_accuracy: 0.9667
# Epoch 59/60
# 2/2 [==============================] - 0s 48ms/step - loss: 0.0938 - accuracy: 0.9786 - val_loss: 0.1403 - val_accuracy: 0.9333
# Epoch 60/60
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1125 - accuracy: 0.9643 - val_loss: 0.1271 - val_accuracy: 0.9500

# %%
# evaluate the model

scores = model.evaluate(X_test, y_test, verbose=0)
scores

# In results, first is loss, second is accuracy
# Out:
# [0.12713126838207245, 0.949999988079071]

# %%
# extract the accuracy from model.evaluate

print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 0.13
# accuracy: 95.00%

# %% [markdown]
# ## Wide and Deep network with RandomGridSearch

# %%
# %%time

# If you don't have the following installed, from command line '!pip install scikeras'
from scikeras.wrappers import KerasClassifier
from keras.initializers import GlorotNormal

score_measure = "accuracy"
kfolds = 5

def build_clf(hidden_layer_sizes, dropout):
    ann = tf.keras.models.Sequential()
    ann.add(keras.layers.Input(shape=9)),
    for hidden_layer_size in hidden_layer_sizes:
        model.add(keras.layers.Dense(hidden_layer_size, kernel_initializer= tf.keras.initializers.GlorotNormal(), 
                                     bias_initializer=keras.initializers.RandomNormal(mean=0.0, stddev=0.05, seed=None), activation="relu"))
        model.add(keras.layers.Dropout(dropout))
    ann.add(tf.keras.layers.Dense(6, activation='softmax'))
    ann.compile(loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
    return ann
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
from scikeras.wrappers import KerasClassifier

keras_clf = KerasClassifier(
    model=build_clf,
    hidden_layer_sizes=64,
    dropout = 0.1
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import RandomizedSearchCV

params = {
    'optimizer__learning_rate': [0.0005, 0.001, 0.005],
    'model__hidden_layer_sizes': [(40,),(50,),(40,20)],
    'model__dropout': [0, 0.1],
    'batch_size':[20, 60, 100],
    'epochs':[10, 50, 100],
    'optimizer':["adam",'sgd']
}
keras_clf.get_params().keys()
# Out:
# dict_keys(['model', 'build_fn', 'warm_start', 'random_state', 'optimizer', 'loss', 'metrics', 'batch_size', 'validation_batch_size', 'verbose', 'callbacks', 'validation_split', 'shuffle', 'run_eagerly', 'epochs', 'hidden_layer_sizes', 'dropout', 'class_weight'])

# %%
rnd_search_cv = RandomizedSearchCV(estimator=keras_clf, param_distributions=params, scoring='accuracy', n_iter=50, cv=5)

import sys
sys.setrecursionlimit(10000) # note: the default is 3000 (python 3.9)

earlystop = EarlyStopping(monitor='val_loss', patience=5, verbose=0, mode='auto')
callback = [earlystop]

_ = rnd_search_cv.fit(X_train, y_train, callbacks=callback, verbose=0)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 80ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 84ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 68ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 66ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 68ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 4ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 76ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 2/2 [==============================] - 0s 4ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 422ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 76ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# ...
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 53ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\wrappers.py", line 1054, in predict
#     y_pred = self.target_encoder_.inverse_transform(y_pred)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\scikeras\utils\transformers.py", line 265, in inverse_transform
#     class_predictions = self._final_encoder.inverse_transform(class_predictions)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\pipeline.py", line 686, in inverse_transform
#     Xt = transform.inverse_transform(Xt)
#   File "C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\preprocessing\_encoders.py", line 1442, in inverse_transform
#     X_tr[:, i] = self.categories_[i][labels.astype("int64", copy=False)]
# IndexError: index 5 is out of bounds for axis 0 with size 5
#
#   warnings.warn(
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.12142857        nan        nan        nan 0.23571429
#         nan        nan 0.19285714 0.21428571        nan 0.50714286
#         nan 0.27857143        nan        nan        nan        nan
#         nan        nan        nan 0.4               nan 0.37857143
#  0.35              nan 0.25714286        nan        nan        nan
#  0.37142857        nan 0.15714286        nan 0.31428571        nan
#         nan        nan 0.55       0.20714286        nan        nan
#  0.27142857 0.63571429 0.57142857        nan 0.42857143        nan
#  0.49285714        nan]
#   warnings.warn(

# %%
rnd_search_cv.best_params_
# Out:
# {'optimizer__learning_rate': 0.0005,
#  'optimizer': 'adam',
#  'model__hidden_layer_sizes': (40, 20),
#  'model__dropout': 0.1,
#  'epochs': 100,
#  'batch_size': 20}

# %%
best_net = rnd_search_cv.best_estimator_
print(rnd_search_cv.best_params_)
# Out:
# {'optimizer__learning_rate': 0.0005, 'optimizer': 'adam', 'model__hidden_layer_sizes': (40, 20), 'model__dropout': 0.1, 'epochs': 100, 'batch_size': 20}

# %%
# %%time
y_pred = best_net.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# 3/3 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            1       0.64      0.83      0.72        30
#            2       0.00      0.00      0.00         4
#            3       0.62      0.56      0.59        18
#            4       0.00      0.00      0.00         5
#            5       0.50      0.67      0.57         3
#
#     accuracy                           0.62        60
#    macro avg       0.35      0.41      0.38        60
# weighted avg       0.53      0.62      0.57        60
#
# CPU times: total: 547 ms
# Wall time: 127 ms
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Jeshwant\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # The accuracy for Nueral Network model(using sklearn) With GridSearchCV is the best with highest accuracy of 97%. keras needs more computation power to run more wide range parameters.
